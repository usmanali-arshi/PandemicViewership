# %%
import pandas as pd
import numpy as np

# %%
df_title = pd.read_csv("title.basics.tsv", sep='\t')
# Out:
# C:\Users\usman\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (4,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df_title.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
df_ratings = pd.read_csv("title.ratings.tsv", sep='\t')

# %%
df_movies = df_title[df_title["titleType"]=="movie"]

# %%
df_movies.head()
# Out:
#         tconst titleType                 primaryTitle  \
# 498  tt0000502     movie                     Bohemios
# 570  tt0000574     movie  The Story of the Kelly Gang
# 610  tt0000615     movie           Robbery Under Arms
# 625  tt0000630     movie                       Hamlet
# 668  tt0000675     movie                  Don Quijote
#
#                    originalTitle isAdult startYear endYear runtimeMinutes  \
# 498                     Bohemios       0      1905      \N            100
# 570  The Story of the Kelly Gang       0      1906      \N             70
# 610           Robbery Under Arms       0      1907      \N             \N
# 625                       Amleto       0      1908      \N             \N
# 668                  Don Quijote       0      1908      \N             \N
#
#                          genres
# 498                          \N
# 570  Action,Adventure,Biography
# 610                       Drama
# 625                       Drama
# ...

# %%
df_movies.drop(labels=['originalTitle'], axis=1, inplace=True)
# Out:
# C:\Users\usman\anaconda3\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df_movies.head()
# Out:
#         tconst titleType                 primaryTitle isAdult startYear  \
# 498  tt0000502     movie                     Bohemios       0      1905
# 570  tt0000574     movie  The Story of the Kelly Gang       0      1906
# 610  tt0000615     movie           Robbery Under Arms       0      1907
# 625  tt0000630     movie                       Hamlet       0      1908
# 668  tt0000675     movie                  Don Quijote       0      1908
#
#     endYear runtimeMinutes                      genres
# 498      \N            100                          \N
# 570      \N             70  Action,Adventure,Biography
# 610      \N             \N                       Drama
# 625      \N             \N                       Drama
# 668      \N             \N                       Drama

# %%
df_movies.drop(labels=['endYear', 'isAdult'], axis=1, inplace=True)

# %%
df_movies.head()
# Out:
#         tconst titleType                 primaryTitle startYear  \
# 498  tt0000502     movie                     Bohemios      1905
# 570  tt0000574     movie  The Story of the Kelly Gang      1906
# 610  tt0000615     movie           Robbery Under Arms      1907
# 625  tt0000630     movie                       Hamlet      1908
# 668  tt0000675     movie                  Don Quijote      1908
#
#     runtimeMinutes                      genres
# 498            100                          \N
# 570             70  Action,Adventure,Biography
# 610             \N                       Drama
# 625             \N                       Drama
# 668             \N                       Drama

# %%
df_movies.dtypes
# Out:
# tconst            object
# titleType         object
# primaryTitle      object
# startYear         object
# runtimeMinutes    object
# genres            object
# dtype: object

# %%
df_movies["startYear"] = pd.to_numeric(df_movies["startYear"], errors='coerce')
# Out:
# <ipython-input-13-8cff2860171b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_movies["startYear"] = pd.to_numeric(df_movies["startYear"], errors='coerce')

# %%
df_movies.dtypes
# Out:
# tconst             object
# titleType          object
# primaryTitle       object
# startYear         float64
# runtimeMinutes     object
# genres             object
# dtype: object

# %%
df_ratings
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.6      1692
# 1        tt0000002            6.0       210
# 2        tt0000003            6.5      1439
# 3        tt0000004            6.1       122
# 4        tt0000005            6.1      2239
# ...            ...            ...       ...
# 1134195  tt9916580            7.2         5
# 1134196  tt9916690            6.6         5
# 1134197  tt9916720            6.3        77
# 1134198  tt9916766            6.9        16
# 1134199  tt9916778            7.5        27
#
# [1134200 rows x 3 columns]

# %%
df_movies_2015 = df_movies[df_movies["startYear"]>2015]

# %%
df_movies_2015
# Out:
#             tconst titleType                               primaryTitle  \
# 11061    tt0011216     movie                             Spanish Fiesta
# 11638    tt0011801     movie                           Tötet nicht mehr
# 61129    tt0062336     movie  El Tango del Viudo y Su Espejo Deformante
# 64104    tt0065392     movie                         Bucharest Memories
# 67683    tt0069049     movie                 The Other Side of the Wind
# ...            ...       ...                                        ...
# 7751768  tt9916270     movie                   Il talento del calabrone
# 7751813  tt9916362     movie                                      Coven
# 7751845  tt9916428     movie                        The Secret of China
# 7751898  tt9916538     movie                        Kuambil Lagi Hatiku
# 7751989  tt9916730     movie                                     6 Gunn
#
#          startYear runtimeMinutes                   genres
# ...
